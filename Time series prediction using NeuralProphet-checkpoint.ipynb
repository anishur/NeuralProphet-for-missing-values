# %%
import pandas as pd
from neuralprophet import NeuralProphet
from matplotlib import pyplot as plt
import pickle

# %%
df_per_day = pd.read_csv('energy_data.csv')
df_per_day.head()
df_per_day.tail()
# Out:
#                  Date  Power (kWh)
# 360  27/03/2014 00:00        18.32
# 361  28/03/2014 00:00        16.65
# 362  29/03/2014 00:00        20.22
# 363  30/03/2014 00:00        25.88
# 364  31/03/2014 00:00        18.43

# %%
df_per_day = df[['Date','Power (kWh)']] 
df_per_day.shape
# Out:
# (365, 2)

# %%
df_per_day.rename(columns={"Date":"ds","Power (kWh)":"y"}, inplace=True)

# %%
#train = df_per_day[:219]
train = df_per_day[:]
test = df_per_day[219:]
#train.tail()

# %%
#Model 

m = NeuralProphet()

# %%
#Fit Model

model = m.fit(train, freq='D', epochs=1000)
# Out:
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=228.0), HTML(value='')))
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.70E-02, min: 1.12E+00
# INFO - (NP.utils_torch.lr_range_test) - learning rate range test selected lr: 3.59E-01
# Epoch[1000/1000]: 100%|████████| 1000/1000 [00:34<00:00, 28.85it/s, SmoothL1Loss=0.0175, MAE=3.36, MSE=20.6, RegLoss=0]

# %%
#Future Date

future_dates = m.make_future_dataframe(train, periods=35)

future_dates.head()
# Out:
#           ds     y         t y_scaled
# 0 2014-12-04  None  1.001433      NaN
# 1 2014-12-05  None  1.002865      NaN
# 2 2014-12-06  None  1.004298      NaN
# 3 2014-12-07  None  1.005731      NaN
# 4 2014-12-08  None  1.007163      NaN

# %%
#Prediction

prediction = m.predict(future_dates)
prediction.head()
# Out:
#           ds     y      yhat1 residual1      trend  season_weekly
# 0 2014-12-04  None  22.526794       NaN  23.058401      -0.531606
# 1 2014-12-05  None  21.797245       NaN  23.072092      -1.274847
# 2 2014-12-06  None  25.148273       NaN  23.085781       2.062492
# 3 2014-12-07  None  26.021210       NaN  23.099470       2.921739
# 4 2014-12-08  None  22.541113       NaN  23.113161      -0.572048

# %%
#plot

m.plot(prediction)

# %%
component = m.plot_components(prediction)
